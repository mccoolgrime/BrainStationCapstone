# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

# %matplotlib inline

# %%
data_gs = pd.read_csv("../data/observations-gregtasney.csv")
data_gs.head()
# Out:
# C:\Users\lisa_\AppData\Local\Temp\ipykernel_26724\3140657315.py:1: DtypeWarning: Columns (15,26,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_gs = pd.read_csv("../data/observations-gregtasney.csv")
#          id                          observed_on_string observed_on  \
# 0  26102174  Sun May 26 2019 07:56:38 GMT+1000 (GMT+10)  2019-05-26
# 1  26102183  Sun May 19 2019 10:45:52 GMT+1000 (GMT+10)  2019-05-19
# 2  26102189  Sun May 19 2019 10:37:34 GMT+1000 (GMT+10)  2019-05-19
# 3  26102706                                         NaN         NaN
# 4  26102759                      2019/05/01 8:04 PM HST  2019-05-01
#
#           time_observed_at time_zone  user_id  user_login    user_name  \
# 0  2019-05-25 21:56:38 UTC  Brisbane  1809954  gregtasney  Greg Tasney
# 1  2019-05-19 00:45:52 UTC  Brisbane  1809954  gregtasney  Greg Tasney
# 2  2019-05-19 00:37:34 UTC  Brisbane  1809954  gregtasney  Greg Tasney
# 3                      NaN    Hawaii  1809954  gregtasney  Greg Tasney
# 4  2019-05-02 06:04:00 UTC    Hawaii  1809954  gregtasney  Greg Tasney
#
#                 created_at               updated_at  ... place_county_name  \
# 0  2019-05-31 06:25:48 UTC  2019-06-02 04:59:50 UTC  ...         Salisbury
# 1  2019-05-31 06:26:15 UTC  2022-10-18 09:01:06 UTC  ...           Corinda
# 2  2019-05-31 06:26:36 UTC  2022-01-25 09:25:37 UTC  ...           Corinda
# 3  2019-05-31 06:55:01 UTC  2023-04-27 13:22:35 UTC  ...           Corinda
# 4  2019-05-31 06:57:25 UTC  2019-06-02 04:59:40 UTC  ...         Salisbury
#
#   place_state_name place_country_name place_admin1_name place_admin2_name  \
# 0       Queensland          Australia        Queensland         Salisbury
# 1       Queensland          Australia        Queensland           Corinda
# 2       Queensland          Australia        Queensland           Corinda
# 3       Queensland          Australia        Queensland           Corinda
# 4       Queensland          Australia        Queensland         Salisbury
#
#      species_guess    scientific_name           common_name  \
# 0    Argina astrea      Argina astrea  crotalaria pod borer
# 1  Lesser Wanderer     Danaus petilia       Lesser Wanderer
# 2    Blue Wanderer    Tirumala hamata         Blue Wanderer
# 3      Burnie Vine  Malaisia scandens           Burnie Vine
# 4    Argina astrea      Argina astrea  crotalaria pod borer
#
#    iconic_taxon_name  taxon_id
# 0            Insecta  318525.0
# 1            Insecta  333775.0
# 2            Insecta  197078.0
# 3            Plantae  705655.0
# 4            Insecta  318525.0
#
# [5 rows x 42 columns]

# %%
data_gs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97617 entries, 0 to 97616
# Data columns (total 42 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                97617 non-null  int64
#  1   observed_on_string                97614 non-null  object
#  2   observed_on                       97614 non-null  object
#  3   time_observed_at                  97594 non-null  object
#  4   time_zone                         97617 non-null  object
#  5   user_id                           97617 non-null  int64
#  6   user_login                        97617 non-null  object
#  7   user_name                         97617 non-null  object
#  8   created_at                        97617 non-null  object
#  9   updated_at                        97617 non-null  object
#  10  quality_grade                     97617 non-null  object
#  11  license                           97617 non-null  object
#  12  url                               97617 non-null  object
#  13  image_url                         97501 non-null  object
#  14  sound_url                         144 non-null    object
#  15  tag_list                          19 non-null     object
#  16  description                       4843 non-null   object
#  17  num_identification_agreements     97617 non-null  int64
#  18  num_identification_disagreements  97617 non-null  int64
#  19  captive_cultivated                97617 non-null  bool
#  20  oauth_application_id              12172 non-null  float64
#  21  place_guess                       97311 non-null  object
#  22  latitude                          97311 non-null  float64
#  23  longitude                         97311 non-null  float64
#  24  positional_accuracy               36605 non-null  float64
#  25  public_positional_accuracy        38015 non-null  float64
#  26  geoprivacy                        462 non-null    object
#  27  taxon_geoprivacy                  33015 non-null  object
#  28  coordinates_obscured              97617 non-null  bool
#  29  positioning_method                73 non-null     object
#  30  positioning_device                73 non-null     object
#  31  place_town_name                   421 non-null    object
#  32  place_county_name                 97296 non-null  object
#  33  place_state_name                  97311 non-null  object
#  34  place_country_name                97311 non-null  object
#  35  place_admin1_name                 97311 non-null  object
#  36  place_admin2_name                 97296 non-null  object
#  37  species_guess                     96350 non-null  object
#  38  scientific_name                   97616 non-null  object
#  39  common_name                       80967 non-null  object
#  40  iconic_taxon_name                 97615 non-null  object
#  41  taxon_id                          97616 non-null  float64
# dtypes: bool(2), float64(6), int64(4), object(30)
# memory usage: 30.0+ MB

# %%
# looking at tail and some of the intermediate columns
data_gs.iloc[-6:-1, 9:23]
# Out:
#                     updated_at quality_grade   license  \
# 97611  2023-12-03 11:56:25 UTC      research  CC-BY-SA
# 97612  2023-12-04 03:02:00 UTC      research  CC-BY-SA
# 97613  2023-12-04 08:24:19 UTC      research  CC-BY-SA
# 97614  2023-12-04 05:07:50 UTC      needs_id  CC-BY-SA
# 97615  2023-12-04 08:25:27 UTC      research  CC-BY-SA
#
#                                                      url  \
# 97611  https://www.inaturalist.org/observations/19285...
# 97612  https://www.inaturalist.org/observations/19285...
# 97613  https://www.inaturalist.org/observations/19285...
# 97614  https://www.inaturalist.org/observations/19285...
# 97615  https://www.inaturalist.org/observations/19285...
#
#                                                image_url  \
# 97611                                                NaN
# 97612                                                NaN
# 97613                                                NaN
# 97614  https://inaturalist-open-data.s3.amazonaws.com...
# 97615                                                NaN
#
#                                                sound_url tag_list description  \
# 97611  https://static.inaturalist.org/sounds/854912.m...      NaN         NaN
# 97612  https://static.inaturalist.org/sounds/854918.m...      NaN         NaN
# 97613  https://static.inaturalist.org/sounds/854919.m...      NaN         NaN
# 97614                                                NaN      NaN         NaN
# 97615  https://static.inaturalist.org/sounds/854922.m...      NaN         NaN
#
#        num_identification_agreements  num_identification_disagreements  \
# 97611                              1                                 0
# 97612                              2                                 0
# 97613                              2                                 0
# 97614                              0                                 0
# 97615                              2                                 0
#
#        captive_cultivated  oauth_application_id  \
# 97611               False                   2.0
# 97612               False                   2.0
# 97613               False                   2.0
# 97614               False                   2.0
# 97615               False                   2.0
#
#                            place_guess   latitude
# 97611  Barney View QLD 4287, Australia -28.272760
# 97612  Barney View QLD 4287, Australia -28.272459
# 97613  Barney View QLD 4287, Australia -28.272466
# 97614  Barney View QLD 4287, Australia -28.272574
# 97615  Barney View QLD 4287, Australia -28.272747

# %%
# suspect user_id is same for all entries, using value_counts to confirm
data_gs["user_id"].value_counts()
# Out:
# 1809954    97617
# Name: user_id, dtype: int64

# %%
# suspect user_login is same for all entries, using value_counts to confirm
data_gs["user_login"].value_counts()
# Out:
# gregtasney    97617
# Name: user_login, dtype: int64

# %%
# suspect user_name is same for all entries, using value_counts to confirm
data_gs["user_name"].value_counts()
# Out:
# Greg Tasney    97617
# Name: user_name, dtype: int64

# %%
# suspect license is all the same, confirmed
data_gs["license"].value_counts()
# Out:
# CC-BY-SA    97617
# Name: license, dtype: int64

# %%
# suspect license is all the same, confirmed
data_gs["oauth_application_id"].value_counts()
# Out:
# 3.0    12091
# 2.0       81
# Name: oauth_application_id, dtype: int64

# %%
# list of columns with null values
col_with_null = []
for col in data_gs.columns:
    if data_gs[col].describe()[0] != data_gs.shape[0]:
        col_with_null.append(col)
print(f'No. of columns with null values = {len(col_with_null)}')
col_with_null
# Out:
# No. of columns with null values = 28
# ['observed_on_string',
#  'observed_on',
#  'time_observed_at',
#  'image_url',
#  'sound_url',
#  'tag_list',
#  'description',
#  'oauth_application_id',
#  'place_guess',
#  'latitude',
#  'longitude',
#  'positional_accuracy',
#  'public_positional_accuracy',
#  'geoprivacy',
#  'taxon_geoprivacy',
#  'positioning_method',
#  'positioning_device',
#  'place_town_name',
#  'place_county_name',
#  'place_state_name',
#  'place_country_name',
#  'place_admin1_name',
#  'place_admin2_name',
#  'species_guess',
#  'scientific_name',
#  'common_name',
#  'iconic_taxon_name',
#  'taxon_id']

# %%
# The columns that contribute to only 5% or fewer of the entries
for col in col_with_null:
    rows_notnull = data_gs[data_gs[col].notnull()].shape[0]
    if rows_notnull <= (data_gs.shape[0] / 20):
        print(col, ":", f'   no. of rows not null = {rows_notnull}\n')
# Out:
# sound_url :    no. of rows not null = 144
#
# tag_list :    no. of rows not null = 19
#
# description :    no. of rows not null = 4843
#
# geoprivacy :    no. of rows not null = 462
#
# positioning_method :    no. of rows not null = 73
#
# positioning_device :    no. of rows not null = 73
#
# place_town_name :    no. of rows not null = 421

# %%
# The columns that have fewer than 1% with null values
for col in col_with_null:
    rows_null = data_gs[data_gs[col].isnull()].shape[0]
    if rows_null <= (data_gs.shape[0] / 100):
        print(col, ":", f'   no. of null rows= {rows_null}\n')
# Out:
# observed_on_string :    no. of null rows= 3
#
# observed_on :    no. of null rows= 3
#
# time_observed_at :    no. of null rows= 23
#
# image_url :    no. of null rows= 116
#
# place_guess :    no. of null rows= 306
#
# latitude :    no. of null rows= 306
#
# longitude :    no. of null rows= 306
#
# place_county_name :    no. of null rows= 321
#
# place_state_name :    no. of null rows= 306
#
# place_country_name :    no. of null rows= 306
#
# place_admin1_name :    no. of null rows= 306
#
# place_admin2_name :    no. of null rows= 321
#
# scientific_name :    no. of null rows= 1
#
# iconic_taxon_name :    no. of null rows= 2
#
# taxon_id :    no. of null rows= 1

# %%
# cursory view of tag_list
data_gs[data_gs['tag_list'].notnull()].iloc[:, :17]
# Out:
#               id       observed_on_string observed_on  \
# 7381    45669589  2013/01/11 5:28 PM AEDT  2013-01-11
# 7382    45669590  2013/01/11 6:23 PM AEDT  2013-01-11
# 76741  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 76820  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 76849  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 77294  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 77746  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 77761  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 77901  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 78071  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 78156  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 78282  https://inaturalist-open-data.s3.amazonaws.com...       NaN
# 78291  https://inaturalist-open-data.s3.amazonaws.com...       NaN
#
#                               tag_list                      description
# 7381              Mt Glorious 12012013                              NaN
# 7382              Mt Glorious 12012013                              NaN
# 7383              Mt Glorious 12012013                              NaN
# 7384                          Tasmania                              NaN
# 7385                          Tasmania                              NaN
# 7386                          Tasmania                              NaN
# 70422                          Unknown                              NaN
# 72536  (Splityard Creek L.Pedley 5360)  (Splityard Creek L.Pedley 5360)
# 76741                            galls            On Acacia terminalis.
# 76820                             Gall                              NaN
# 76849                             gall            Galls on Leptospermum
# 77294                             gall  On Hedraianthera porphyropetala
# 77746                            Galls   Galls on Alectryon tomentosus.
# 77761                            Galls               On Acacia salicina
# 77901                             gall                              NaN
# 78071                            galls               galls on S.smithii
# 78156                            galls       On Eucalyptus campanulata.
# 78282                            galls      Galls on solanu Stelligerum
# 78291                             gall    Gall on Syncarpia glomulifera

# %%
# cursory view of descriptions 
data_gs[data_gs['description'].notnull()]['description']
# Out:
# 17                                    Planted early 2000's
# 104                                            On Myoporum
# 113                Escaped or dumped pet. Pet trade morph.
# 171      No records on iNaturlist. It's a common plant ...
# 265      I prefer Oplismenus aemulus which iNaturlist h...
#                                ...
# 97484                                  On Smilax australis
# 97487        Pandorea sp. (Mt Maroon P.I.Forster+ PIF7111)
# 97517                          N.punctata or N.longifolia.
# 97545                                   A strange outlier.
# 97562    Terrible pics. Just couldn't get the short len...
# Name: description, Length: 4843, dtype: object

# %%
# percent of entries with data from description column
data_gs[data_gs['description'].notnull()].shape[0] / data_gs.shape[0]
# Out:
# 0.04961226015960335

# %%
# cursory view of latitude nulls
data_gs[data_gs['latitude'].isnull()].iloc[:, 21:37]
# Out:
#       place_guess  latitude  longitude  positional_accuracy  \
# 6789          NaN       NaN        NaN                 10.0
# 11292         NaN       NaN        NaN                  NaN
# 11373         NaN       NaN        NaN               1118.0
# 11380         NaN       NaN        NaN                 65.0
# 11389         NaN       NaN        NaN               1055.0
# ...           ...       ...        ...                  ...
# 88333         NaN       NaN        NaN                  NaN
# 88334         NaN       NaN        NaN                  NaN
# 88335         NaN       NaN        NaN                  NaN
# 88336         NaN       NaN        NaN                  NaN
# 91850         NaN       NaN        NaN                  NaN
#
#        public_positional_accuracy geoprivacy taxon_geoprivacy  \
# 6789                      29727.0    private         obscured
# 11292                     29680.0    private         obscured
# 11373                     29680.0    private         obscured
# 11380                     29680.0    private         obscured
# 11389                     29680.0    private         obscured
# ...                           ...        ...              ...
# 88333                     29680.0    private              NaN
# 88334                     29680.0    private             open
# 88335                     29680.0    private              NaN
# 88336                     29680.0    private              NaN
# 91850                         NaN        NaN              NaN
#
#        coordinates_obscured positioning_method positioning_device  \
# 6789                   True                NaN                NaN
# 11292                  True                NaN                NaN
# 11373                  True                NaN                NaN
# 11380                  True                NaN                NaN
# 11389                  True                NaN                NaN
# ...                     ...                ...                ...
# 88333                  True                NaN                NaN
# 88334                  True                NaN                NaN
# 88335                  True                NaN                NaN
# 88336                  True                NaN                NaN
# 91850                 False                NaN                NaN
#
#       place_town_name place_county_name place_state_name place_country_name  \
# 6789              NaN               NaN              NaN                NaN
# 11292             NaN               NaN              NaN                NaN
# 11373             NaN               NaN              NaN                NaN
# 11380             NaN               NaN              NaN                NaN
# 11389             NaN               NaN              NaN                NaN
# ...               ...               ...              ...                ...
# 88333             NaN               NaN              NaN                NaN
# 88334             NaN               NaN              NaN                NaN
# 88335             NaN               NaN              NaN                NaN
# 88336             NaN               NaN              NaN                NaN
# 91850             NaN               NaN              NaN                NaN
#
#       place_admin1_name place_admin2_name
# 6789                NaN               NaN
# 11292               NaN               NaN
# 11373               NaN               NaN
# 11380               NaN               NaN
# 11389               NaN               NaN
# ...                 ...               ...
# 88333               NaN               NaN
# 88334               NaN               NaN
# 88335               NaN               NaN
# 88336               NaN               NaN
# 91850               NaN               NaN
#
# [306 rows x 16 columns]

# %%
#Geoprivacy can be converted to dummies IF removal of missing lat and lon leaves anything other than NaN
data_gs["geoprivacy"].value_counts()
# Out:
# private     305
# obscured    157
# Name: geoprivacy, dtype: int64

# %%
#taxon_geoprivacy can be converted to dummies IF removal of missing lat and lon leaves anything other than open
data_gs["taxon_geoprivacy"].value_counts()
# Out:
# open        31363
# obscured     1652
# Name: taxon_geoprivacy, dtype: int64

# %%
# cursory view of latitude not nulls
data_gs[data_gs['latitude'].notnull()].iloc[:, 21:37]
# Out:
#                                  place_guess   latitude   longitude  \
# 0         Russ Hall Park, Salisbury, QLD, AU -27.550703  153.034180
# 1         87 Archer Parade, Corinda, QLD, AU -27.548263  152.994475
# 2      430 Cliveden Avenue, Corinda, QLD, AU -27.550458  152.993713
# 3                    Brisbane QLD, Australia -27.550470  152.994234
# 4                    Brisbane QLD, Australia -27.550649  153.034376
# ...                                      ...        ...         ...
# 97612        Barney View QLD 4287, Australia -28.272459  152.769096
# 97613        Barney View QLD 4287, Australia -28.272466  152.769034
# 97614        Barney View QLD 4287, Australia -28.272574  152.769949
# 97615        Barney View QLD 4287, Australia -28.272747  152.769823
# 97616      Burnett Creek QLD 4310, Australia -28.244983  152.551623
#
#        positional_accuracy  public_positional_accuracy geoprivacy  \
# 0                      5.0                         5.0        NaN
# 1                      5.0                         5.0        NaN
# 2                      5.0                         5.0        NaN
# 3                     15.0                        15.0        NaN
# 4                      NaN                         NaN        NaN
# ...                    ...                         ...        ...
# 97612                 77.0                        77.0        NaN
# 97613                 80.0                        80.0        NaN
# 97614                 35.0                        35.0        NaN
# 97615                 49.0                        49.0        NaN
# 97616                 31.0                        31.0        NaN
#
#       taxon_geoprivacy  coordinates_obscured positioning_method  \
# 0                  NaN                 False                NaN
# 1                  NaN                 False                NaN
# 2                  NaN                 False                NaN
# 3                  NaN                 False                NaN
# 4                  NaN                 False                NaN
# ...                ...                   ...                ...
# 97612             open                 False                gps
# 97613             open                 False                gps
# 97614              NaN                 False                gps
# 97615             open                 False                NaN
# 97616              NaN                 False                NaN
#
#       positioning_device place_town_name   place_county_name place_state_name  \
# 0                    NaN             NaN           Salisbury       Queensland
# 1                    NaN             NaN             Corinda       Queensland
# 2                    NaN             NaN             Corinda       Queensland
# 3                    NaN             NaN             Corinda       Queensland
# 4                    NaN             NaN           Salisbury       Queensland
# ...                  ...             ...                 ...              ...
# 97612                gps             NaN  Beaudesert  - Pt C       Queensland
# 97613                gps             NaN  Beaudesert  - Pt C       Queensland
# 97614                gps             NaN  Beaudesert  - Pt C       Queensland
# 97615                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97616                NaN             NaN              Boonah       Queensland
#
#       place_country_name place_admin1_name   place_admin2_name
# 0              Australia        Queensland           Salisbury
# 1              Australia        Queensland             Corinda
# 2              Australia        Queensland             Corinda
# 3              Australia        Queensland             Corinda
# 4              Australia        Queensland           Salisbury
# ...                  ...               ...                 ...
# 97612          Australia        Queensland  Beaudesert  - Pt C
# 97613          Australia        Queensland  Beaudesert  - Pt C
# 97614          Australia        Queensland  Beaudesert  - Pt C
# 97615          Australia        Queensland  Beaudesert  - Pt C
# 97616          Australia        Queensland              Boonah
#
# [97311 rows x 16 columns]

# %%
# table for count of entries by county
data_gs['place_county_name'].value_counts()
# Out:
# Salisbury                                  5493
# Guanaba-Springbrook                        4845
# Brookfield (incl. Brisbane Forest Park)    4756
# Caloundra - Rail Corridor                  4558
# Boonah                                     4142
#                                            ...
# San Francisco                                 1
# Dakabin-Kallangur-M. Downs                    1
# Spring Hill                                   1
# Jamboree Heights                              1
# Launceston - Pt B                             1
# Name: place_county_name, Length: 267, dtype: int64

# %%
# table for place_admin2_name shows it's highly likely it is duplicate info to place_county_name
data_gs['place_admin2_name'].value_counts()
# Out:
# Salisbury                                  5493
# Guanaba-Springbrook                        4845
# Brookfield (incl. Brisbane Forest Park)    4756
# Caloundra - Rail Corridor                  4558
# Boonah                                     4142
#                                            ...
# San Francisco                                 1
# Dakabin-Kallangur-M. Downs                    1
# Spring Hill                                   1
# Jamboree Heights                              1
# Launceston - Pt B                             1
# Name: place_admin2_name, Length: 267, dtype: int64

# %%
# table for count of entries by state
data_gs['place_state_name'].value_counts()
# Out:
# Queensland                      91450
# New South Wales                  2986
# Western Australia                2368
# Australian Capital Territory      499
# Tasmania                            7
# California                          1
# Name: place_state_name, dtype: int64

# %%
# table for place_admin1_name shows it's highly likely it is duplicate info to place_state_name
data_gs['place_admin1_name'].value_counts()
# Out:
# Queensland                      91450
# New South Wales                  2986
# Western Australia                2368
# Australian Capital Territory      499
# Tasmania                            7
# California                          1
# Name: place_admin1_name, dtype: int64

# %%
# table for count of entry by country shows all but one entry is in Australia
data_gs['place_country_name'].value_counts()
# Out:
# Australia        97310
# United States        1
# Name: place_country_name, dtype: int64

# %%
# explore columns 21 - 33 together for better understanding of positional accuracy nulls
data_gs[data_gs["positional_accuracy"].isnull()].iloc[:, 21:34]
# Out:
#                            place_guess   latitude   longitude  \
# 4              Brisbane QLD, Australia -27.550649  153.034376
# 9              Brisbane QLD, Australia -27.549833  153.033437
# 10             Brisbane QLD, Australia -27.549830  153.033446
# 11             Brisbane QLD, Australia -27.549974  153.033748
# 14             Brisbane QLD, Australia -27.550545  153.034303
# ...                                ...        ...         ...
# 97602  Barney View QLD 4287, Australia -28.271257  152.768784
# 97603  Barney View QLD 4287, Australia -28.271368  152.768799
# 97604  Barney View QLD 4287, Australia -28.271406  152.768814
# 97605  Barney View QLD 4287, Australia -28.271349  152.768875
# 97606  Barney View QLD 4287, Australia -28.271364  152.768906
#
#        positional_accuracy  public_positional_accuracy geoprivacy  \
# 4                      NaN                         NaN        NaN
# 9                      NaN                         NaN        NaN
# 10                     NaN                         NaN        NaN
# 11                     NaN                         NaN        NaN
# 14                     NaN                         NaN        NaN
# ...                    ...                         ...        ...
# 97602                  NaN                         NaN        NaN
# 97603                  NaN                         NaN        NaN
# 97604                  NaN                         NaN        NaN
# 97605                  NaN                         NaN        NaN
# 97606                  NaN                         NaN        NaN
#
#       taxon_geoprivacy  coordinates_obscured positioning_method  \
# 4                  NaN                 False                NaN
# 9                  NaN                 False                NaN
# 10                 NaN                 False                NaN
# 11                 NaN                 False                NaN
# 14                 NaN                 False                NaN
# ...                ...                   ...                ...
# 97602              NaN                 False                NaN
# 97603              NaN                 False                NaN
# 97604              NaN                 False                NaN
# 97605             open                 False                NaN
# 97606              NaN                 False                NaN
#
#       positioning_device place_town_name   place_county_name place_state_name
# 4                    NaN             NaN           Salisbury       Queensland
# 9                    NaN             NaN           Salisbury       Queensland
# 10                   NaN             NaN           Salisbury       Queensland
# 11                   NaN             NaN           Salisbury       Queensland
# 14                   NaN             NaN           Salisbury       Queensland
# ...                  ...             ...                 ...              ...
# 97602                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97603                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97604                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97605                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97606                NaN             NaN  Beaudesert  - Pt C       Queensland
#
# [61012 rows x 13 columns]

# %%
# explore columns 21 - 33 together for better understanding of positional accuracy when present
data_gs[data_gs["positional_accuracy"].notnull()].iloc[:, 21:34]
# Out:
#                                  place_guess   latitude   longitude  \
# 0         Russ Hall Park, Salisbury, QLD, AU -27.550703  153.034180
# 1         87 Archer Parade, Corinda, QLD, AU -27.548263  152.994475
# 2      430 Cliveden Avenue, Corinda, QLD, AU -27.550458  152.993713
# 3                    Brisbane QLD, Australia -27.550470  152.994234
# 5                    Brisbane QLD, Australia -27.550324  153.033956
# ...                                      ...        ...         ...
# 97612        Barney View QLD 4287, Australia -28.272459  152.769096
# 97613        Barney View QLD 4287, Australia -28.272466  152.769034
# 97614        Barney View QLD 4287, Australia -28.272574  152.769949
# 97615        Barney View QLD 4287, Australia -28.272747  152.769823
# 97616      Burnett Creek QLD 4310, Australia -28.244983  152.551623
#
#        positional_accuracy  public_positional_accuracy geoprivacy  \
# 0                      5.0                         5.0        NaN
# 1                      5.0                         5.0        NaN
# 2                      5.0                         5.0        NaN
# 3                     15.0                        15.0        NaN
# 5                      4.0                         4.0        NaN
# ...                    ...                         ...        ...
# 97612                 77.0                        77.0        NaN
# 97613                 80.0                        80.0        NaN
# 97614                 35.0                        35.0        NaN
# 97615                 49.0                        49.0        NaN
# 97616                 31.0                        31.0        NaN
#
#       taxon_geoprivacy  coordinates_obscured positioning_method  \
# 0                  NaN                 False                NaN
# 1                  NaN                 False                NaN
# 2                  NaN                 False                NaN
# 3                  NaN                 False                NaN
# 5                  NaN                 False                NaN
# ...                ...                   ...                ...
# 97612             open                 False                gps
# 97613             open                 False                gps
# 97614              NaN                 False                gps
# 97615             open                 False                NaN
# 97616              NaN                 False                NaN
#
#       positioning_device place_town_name   place_county_name place_state_name
# 0                    NaN             NaN           Salisbury       Queensland
# 1                    NaN             NaN             Corinda       Queensland
# 2                    NaN             NaN             Corinda       Queensland
# 3                    NaN             NaN             Corinda       Queensland
# 5                    NaN             NaN           Salisbury       Queensland
# ...                  ...             ...                 ...              ...
# 97612                gps             NaN  Beaudesert  - Pt C       Queensland
# 97613                gps             NaN  Beaudesert  - Pt C       Queensland
# 97614                gps             NaN  Beaudesert  - Pt C       Queensland
# 97615                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97616                NaN             NaN              Boonah       Queensland
#
# [36605 rows x 13 columns]

# %%
# boxplot of positional accuracy non null values
PA_notnull = pd.DataFrame(data_gs[data_gs["positional_accuracy"].notnull()]["positional_accuracy"])
sns.boxplot(x = "positional_accuracy", data = PA_notnull).set_title("Spread of Positional Accuracy Values")
print(f'The non null set of positional_accuracy has {PA_notnull.shape[0]} values')
# Out:
# The non null set of positional_accuracy has 36605 values

# %%
# again with removal of extreme outliers
Limit = 100000
sns.boxplot(x = "positional_accuracy", data = PA_notnull[PA_notnull["positional_accuracy"] < Limit]).set_title("Spread of Positional Accuracy Values")
print(f'The non null set of positional_accuracy with values less than {Limit} has {PA_notnull[PA_notnull["positional_accuracy"] < Limit].shape[0]} values')
# Out:
# The non null set of positional_accuracy with values less than 100000 has 36602 values

# %%
PA_notnull.describe()
# Out:
#        positional_accuracy
# count         36605.000000
# mean            301.556782
# std            5025.390953
# min               1.000000
# 25%               5.000000
# 50%              11.000000
# 75%              31.000000
# max          890308.000000

# %%
# again with removal of extreme outliers
Limit = 50
sns.boxplot(x = "positional_accuracy", data = PA_notnull[PA_notnull["positional_accuracy"] < Limit]).set_title("Spread of Positional Accuracy Values")
print(f'The non null set of positional_accuracy with values less than {Limit} has {PA_notnull[PA_notnull["positional_accuracy"] < Limit].shape[0]} values')
# Out:
# The non null set of positional_accuracy with values less than 50 has 28950 values

# %%
# iNaturalist website names positional accuracy of 30 m or less necessary for some types of analysis
Limit = 30
print(f'The non null set of positional_accuracy with values less than {Limit} has {PA_notnull[PA_notnull["positional_accuracy"] < Limit].shape[0]} values')
# Out:
# The non null set of positional_accuracy with values less than 30 has 25237 values

# %%
# cursory view of null species_guess
data_gs[data_gs["species_guess"].isnull()]
# Out:
# 91250            Boonah       Queensland          Australia        Queensland
# 91850               NaN              NaN                NaN               NaN
#
#       place_admin2_name species_guess          scientific_name  \
# 8             Salisbury           NaN              Ellipsidion
# 229               Oxley           NaN         Typha orientalis
# 319           Salisbury           NaN                  Cyathus
# 326             Corinda           NaN  Utetheisa lotrix lotrix
# 337           Salisbury           NaN                 Pergidae
# ...                 ...           ...                      ...
# 89951            Deagon           NaN               Eucyclodes
# 90095         Salisbury           NaN                 Simaetha
# 90185        Broadsound           NaN           Scolopendridae
# 91250            Boonah           NaN       Acacia acrionastes
# 91850               NaN           NaN                      NaN
#
#                    common_name  iconic_taxon_name  taxon_id
# 8                          NaN            Insecta  123759.0
# 229           Oriental Cattail            Plantae  341639.0
# 319                        NaN              Fungi   68301.0
# 326            Crotalaria Moth            Insecta  694983.0
# 337            Pergid Sawflies            Insecta  201415.0
# ...                        ...                ...       ...
# 89951                      NaN            Insecta  155505.0
# 90095                      NaN          Arachnida  368389.0
# 90185  Scolopendrid Centipedes           Animalia   53764.0
# 91250                      NaN            Plantae  898576.0
# 91850                      NaN                NaN       NaN
#
# [1267 rows x 42 columns]

# %%
# cursory view of null iconic_taxon_name
data_gs[data_gs["iconic_taxon_name"].isnull()]
# Out:
#               id       observed_on_string observed_on  \
# 39124  103797739  2021/12/26 8:29 PM AEDT  2021-12-26
# 91850  184797523                      NaN         NaN
#
#               time_observed_at time_zone  user_id  user_login    user_name  \
# 39124  2021-12-26 09:29:00 UTC    Sydney  1809954  gregtasney  Greg Tasney
# 91850                      NaN    Sydney  1809954  gregtasney  Greg Tasney
#
#                     created_at               updated_at  ...  \
# 39124  2021-12-28 03:19:46 UTC  2023-09-09 06:56:40 UTC  ...
# 91850  2023-09-25 01:26:38 UTC  2023-09-25 01:26:38 UTC  ...
#
#                place_county_name place_state_name place_country_name  \
# 39124  Caloundra - Rail Corridor       Queensland          Australia
# 91850                        NaN              NaN                NaN
#
#       place_admin1_name          place_admin2_name species_guess  \
# 39124        Queensland  Caloundra - Rail Corridor          Life
# 91850               NaN                        NaN           NaN
#
#       scientific_name  common_name  iconic_taxon_name  taxon_id
# 39124            Life         Life                NaN   48460.0
# 91850             NaN          NaN                NaN       NaN
#
# [2 rows x 42 columns]

# %%
# cursory view of null common name
data_gs[data_gs["common_name"].isnull()]
# Out:
#               id                          observed_on_string observed_on  \
# 8       26102900                      2018/10/29 8:38 PM HST  2018-10-29
# 12      26102952                      2019/04/28 2:20 PM HST  2019-04-28
# 14      26102973                      2019/04/04 8:34 PM HST  2019-04-04
# 21      26104403  Sat May 11 2019 14:59:53 GMT+1000 (GMT+10)  2019-05-11
# 31      26104888  Sun Mar 10 2019 08:18:15 GMT+1000 (GMT+10)  2019-03-10
# ...          ...                                         ...         ...
# 97583  192812799                          2023/11/29 5:53 PM  2023-11-29
# 97594  192812813                          2023/11/29 6:01 PM  2023-11-29
# 97602  192812823                          2023/11/29 6:10 PM  2023-11-29
# 97603  192812824                          2023/11/29 6:12 PM  2023-11-29
# 97616  192856161                          2023/11/27 7:14 AM  2023-11-27
#
#               time_observed_at time_zone  user_id  user_login    user_name  \
# 14             Pseudorhynchus lessonii          NaN            Insecta
# 21                Lilioceris bakewelli          NaN            Insecta
# 31                Rostellularia obtusa          NaN            Plantae
# ...                                ...          ...                ...
# 97583  Everistia vacciniifolia nervosa          NaN            Plantae
# 97594          Gynochthodes canthoides          NaN            Plantae
# 97602        Dianella brevipedunculata          NaN            Plantae
# 97603                         Erebinae          NaN            Insecta
# 97616                 Solanum limitare          NaN            Plantae
#
#         taxon_id
# 8       123759.0
# 12      375593.0
# 14     1478488.0
# 21      568055.0
# 31      933215.0
# ...          ...
# 97583   895386.0
# 97594  1039656.0
# 97602   543982.0
# 97603   122426.0
# 97616  1094817.0
#
# [16650 rows x 42 columns]

# %%
# cursory view of null positioning_method
data_gs[data_gs["positioning_method"].isnull()].iloc[:,21:34]
# Out:
#                                  place_guess   latitude   longitude  \
# 0         Russ Hall Park, Salisbury, QLD, AU -27.550703  153.034180
# 1         87 Archer Parade, Corinda, QLD, AU -27.548263  152.994475
# 2      430 Cliveden Avenue, Corinda, QLD, AU -27.550458  152.993713
# 3                    Brisbane QLD, Australia -27.550470  152.994234
# 4                    Brisbane QLD, Australia -27.550649  153.034376
# ...                                      ...        ...         ...
# 97606        Barney View QLD 4287, Australia -28.271364  152.768906
# 97607        Barney View QLD 4287, Australia -28.271178  152.768654
# 97611        Barney View QLD 4287, Australia -28.272760  152.770065
# 97615        Barney View QLD 4287, Australia -28.272747  152.769823
# 97616      Burnett Creek QLD 4310, Australia -28.244983  152.551623
#
#        positional_accuracy  public_positional_accuracy geoprivacy  \
# 0                      5.0                         5.0        NaN
# 1                      5.0                         5.0        NaN
# 2                      5.0                         5.0        NaN
# 3                     15.0                        15.0        NaN
# 4                      NaN                         NaN        NaN
# ...                    ...                         ...        ...
# 97606                  NaN                         NaN        NaN
# 97607                  4.0                         4.0        NaN
# 97611                 54.0                        54.0        NaN
# 97615                 49.0                        49.0        NaN
# 97616                 31.0                        31.0        NaN
#
#       taxon_geoprivacy  coordinates_obscured positioning_method  \
# 0                  NaN                 False                NaN
# 1                  NaN                 False                NaN
# 2                  NaN                 False                NaN
# 3                  NaN                 False                NaN
# 4                  NaN                 False                NaN
# ...                ...                   ...                ...
# 97606              NaN                 False                NaN
# 97607             open                 False                NaN
# 97611              NaN                 False                NaN
# 97615             open                 False                NaN
# 97616              NaN                 False                NaN
#
#       positioning_device place_town_name   place_county_name place_state_name
# 0                    NaN             NaN           Salisbury       Queensland
# 1                    NaN             NaN             Corinda       Queensland
# 2                    NaN             NaN             Corinda       Queensland
# 3                    NaN             NaN             Corinda       Queensland
# 4                    NaN             NaN           Salisbury       Queensland
# ...                  ...             ...                 ...              ...
# 97606                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97607                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97611                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97615                NaN             NaN  Beaudesert  - Pt C       Queensland
# 97616                NaN             NaN              Boonah       Queensland
#
# [97544 rows x 13 columns]

# %%
# cursory view of not null positioning_method
data_gs[data_gs["positioning_method"].notnull()].iloc[:,21:34]
# Out:
#                                              place_guess   latitude  \
# 91584                      Salisbury QLD 4107, Australia -27.550275
# 91887  Tom O'Hara Park, Leichhardt River Road, Kalkad... -20.684130
# 92372                      Salisbury QLD 4107, Australia -27.550093
# 92373  CXCR+Q9 Lookout Archerfield Wetland, Willawong... -27.577753
# 92374  McCarthy Rd at Russ Hall Park, stop 45, Salisb... -27.549900
# ...                                                  ...        ...
# 97609                    Barney View QLD 4287, Australia -28.272321
# 97610                    Barney View QLD 4287, Australia -28.273661
# 97612                    Barney View QLD 4287, Australia -28.272459
# 97613                    Barney View QLD 4287, Australia -28.272466
# 97614                    Barney View QLD 4287, Australia -28.272574
#
#         longitude  positional_accuracy  public_positional_accuracy geoprivacy  \
# 91584  153.034318                285.0                       285.0        NaN
# 91887  139.495478                189.0                       189.0        NaN
# 92372  153.033900                 59.0                        59.0        NaN
# 92373  152.991075                124.0                       124.0        NaN
# 92374  153.033699                 75.0                        75.0        NaN
# ...           ...                  ...                         ...        ...
# 97609  152.770096                 69.0                        69.0        NaN
# 97610  152.770207                 44.0                        44.0        NaN
# 97612  152.769096                 77.0                        77.0        NaN
# 97613  152.769034                 80.0                        80.0        NaN
# 97614  152.769949                 35.0                        35.0        NaN
#
#       taxon_geoprivacy  coordinates_obscured positioning_method  \
# 91584              NaN                 False                gps
# 91887              NaN                 False                gps
# 92372              NaN                 False                gps
# 92373              NaN                 False                gps
# 92374              NaN                 False                gps
# ...                ...                   ...                ...
# 97609             open                 False                gps
# 97610             open                 False                gps
# 97612             open                 False                gps
# 97613             open                 False                gps
# 97614              NaN                 False                gps
#
#       positioning_device place_town_name   place_county_name place_state_name
# 91584                gps             NaN           Salisbury       Queensland
# 91887                gps             NaN           Mount Isa       Queensland
# 92372                gps             NaN           Salisbury       Queensland
# 92373                gps             NaN           Willawong       Queensland
# 92374                gps             NaN           Salisbury       Queensland
# ...                  ...             ...                 ...              ...
# 97609                gps             NaN  Beaudesert  - Pt C       Queensland
# 97610                gps             NaN  Beaudesert  - Pt C       Queensland
# 97612                gps             NaN  Beaudesert  - Pt C       Queensland
# 97613                gps             NaN  Beaudesert  - Pt C       Queensland
# 97614                gps             NaN  Beaudesert  - Pt C       Queensland
#
# [73 rows x 13 columns]

# %%
data_gs["positioning_method"].value_counts()
# Out:
# gps    73
# Name: positioning_method, dtype: int64

# %%
# both positioning_method and position_device only have 73 entries of "gps"
data_gs["positioning_device"].value_counts()
# Out:
# gps    73
# Name: positioning_device, dtype: int64

# %% [markdown]
# ## Notes on Cleaning:
#
# 1. id:  __leave in place__
# 1. observed_on_string:  __DELETE COLUMN__ (duplicate into of observed_on)
# 1. observed_on: __leave in place__ (only three null values which will be deleted when time_observed_at is cleaned)
# 1. time_observed_at: __DELETE 23 NULL ROWS__ (very key information and very small set for deletion)
# 1. user_id: __DELETE COLUMN__ redundant--simply says all data is Greg's
# 1. user login: __DELETE COLUMN__ redundant--simply says all data is Greg's
# 1. user_name: __DELETE COLUMN__ redundant--simply says all data is Greg's
# 1. created_at: __leave in place__
# 1. updated_at: __leave in place__
# 1. quality_grade: __leave in place__
# 1. license: __DELETE COLUMN__ all entries are identical
# 1. url: __leave in place for now__
# 1. image_url: __CONVERT TO BINARY__ (if an image_url exists, 1, else 0)
# 1. sound_url: __CONVERT TO BINARY__ (if a sound_url exists, 1, else 0)
# 1. tag_list: __CONVERT TO BINARY__ (present or not, only 19 entries that have data here, mabye delete later)
# 1. description: __CONVERT TO BINARY__ (present or not; VERY INTERESTING but not likely useful for current analysis and contributes to less than 5% of the entries)
# 1. num_identification_agreements: __leave in place__
# 1. num_identification_disagreements: __leave in place__
# 1. captive_cultivated: __leave in place__
# 1. oauth_application_id: __DUMMY VARIABLE__ (only 2.0 or 3.0 or null)
# 1. place_guess: __leave in place__ (same removal as longitude and latitude--keep in separate data base)
# 1. latitude: __REMOVE 306 NULL ROWS__ (same removal as longitude and place_guess--keep in separate data base)
# 1. longitude: __REMOVE 306 NULL ROWS__ (same removal as latitude and place_guess--keep in separate data base) \
# 1. positional_accuracy: see note below
# 1. public_positional_accuracy: see note below
# 1. geoprivacy: __DUMMY__ (private or obscured) IF removal of missing lat, lon leaves anything other than null
# 1. taxon_geoprivacy: __DUMMY__ (open or obscured) IF removal of missing lat, lon leaves anything other than open
# 1. coordinates_obscured: __leave in place__ (already binary) UNLESS removal of missing lat, long leaves only 1 response
# 1. positioning_method: __DELETE COLUMN__ user input only 73 entries and not helpful
# 1. positioning_device: __DELETE COLUMN__ duplicate of above
# 1. place_town name: __DELETE COLUMN__ only 421 entries, and can be reconstructed from lat/lon
# 1. place_county_name: __IMPUTE FROM LAT, LON__ (assume that this plus deleting missing lat/lon will cover it)
# 1. place_state_name: __leave in place__ (assuming removal of 306 missing lat/lon leaves no more nulls here)
# 1. place_country_name: __leave in place__ (assuming removal of 306 missing lat/lon leaves no more nulls here)
# 1. place_admin1_name: __DELETE COLUMN__ redundant with place_state_name
# 1. place_admin2_name: __DELETE COLUMN__ redundant with place_county_name
# 1. species_guess: __OPTIONS__ impute from other info (although 1267 entries), delete column, re-import other data with genus name
# 1. scientific_name:__leave in place__ (removal of iconic_taxon_name nulls will remove this null)
# 1. common_name: __DELETE COLUMN__ (can be reconstructed if needed from other data, esp if I bring in genus...)
# 1. iconic_taxon_name:__DELETE ROWS__ (only two entries)
# 1. taxon_id: __leave in place__ (removal of iconic_taxon_name nulls will remove this null)

# %% [markdown]
# **On positional accuracy** \
# 63% of this user's lat and lon do not specify positional accuracy. \
# That makes it a potentially problematic dataset to train on. \
# Some options:
# - pretend it doesn't matter, delete column and see what happens with lat/lon
# - cut set down to specified accuracies (36605)
# - look at other large datasets on iNaturalist to see if positional accuracies are better records (and better overall--only 25237 entries have positional accuracy of 30 m or less)
# - write to the user to see if he is willing to explain the lack (perhaps most are accurate, but he didn't note it)
# - might be interesting to develop models on other users with better positional accuracy and then see how well it predicts here
# \
# \
# [For more information about positional accuracy see this link](https://www.inaturalist.org/posts/2035-observation-location-accuracy)

# %% [markdown]
# ## Questions for Stephen/in general
#
# - Should the urls be saved in a different table? The way that SQL organizes dataframes?
# - Should tag list and descriptions be turned to binary (present or not?)
# - For research: What is a license? Is it unique to every user?
# - how do I double check for sure that place_admin2_name is same as place_county_name?
# - how much of my code needs to be commented for this?
